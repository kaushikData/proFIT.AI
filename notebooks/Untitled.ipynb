# %%
from bs4 import BeautifulSoup as bs
with open("/Users/kaushik-shakkari/Downloads/test.htm") as fd:
    data=fd.read()
soup=bs(data,"lxml")
print(soup.find_all("section",class_=""))
# Out:
# [<section class="artdeco-toasts" id="artdeco-toasts">
# <header class="artdeco-toasts__header">
# <h2 class="artdeco-toasts__title">
#         0 notifications total
#       </h2>
# </header>
# <!-- -->
# <ul aria-atomic="true" aria-live="assertive" class="artdeco-toasts_toasts">
# <!-- --> </ul>
# </section>, <section class="pv-ad-banner--light ad-banner-container is-header-zone ember-view" id="ember50" render-method="default"><iframe class="ad-banner" height="17" scrolling="no" src="./(11) Mike Yung _ LinkedIn_files/saved_resource.html" title="advertisement" width="100%"></iframe>
# <!-- --></section>, <section class="pv-top-card artdeco-card ember-view" id="ember53"><!-- -->
# <div class="profile-background-image ember-view" id="ember54" tabindex="0"> <div class="profile-background-image__image-container">
# ...
