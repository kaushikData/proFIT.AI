# %%
# Load libraries
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.chrome.options import Options

linkedin = 'https://www.linkedin.com/login?fromSignIn=true&trk=guest_homepage-basic_nav-header-signin'

opts = Options()

opts.add_argument("user_agent = Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36")

# Open Selenium
#browser = webdriver.Firefox(executable_path='/Users/kaushik-shakkari/Downloads/geckodriver')
browser = webdriver.Chrome(executable_path='/Users/kaushik-shakkari/Downloads/chromedriver',chrome_options=opts)
browser.get(linkedin)
time.sleep(3)
# Identify email and password inputs and enter in information
email = browser.find_element_by_name('session_key')
password = browser.find_element_by_name('session_password')
email.send_keys("shakkari@usc.edu")
password.send_keys("biglion333")

browser.find_element_by_xpath('//*[@type="submit"]').click()

time.sleep(3)
# Out:
# /Users/kaushik-shakkari/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: use options instead of chrome_options

# %%
#EMPLOYEE = 1000 #int(raw_input("Enter number of results: "))

start_page = 1
end_page = 2

roles = ['hardware%20engineer', 'construction%20engineer', 'technical%20writer', 'concept%20artist']

final_df = pd.DataFrame(columns = ['name', 'title', 'location', 'profile','role'])

for role in roles:
    df = pd.DataFrame(columns = ['name', 'title', 'location', 'profile','role'])
    static_search = 'https://www.linkedin.com/search/results/people/?keywords='+ role + '&origin=GLOBAL_SEARCH_HEADER'
    
    cur_page = start_page
    # Go through pages and download data
    while cur_page <= end_page:
        
        if cur_page == 1:
            search = static_search + '&title=' + role
        else:
            print ("hello ", cur_page)
            search = static_search + '&page=' + str(cur_page)
            
        browser.get(search)
        time.sleep(3)
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")    

        # Start scraping and filling in the dataframe
        page = BeautifulSoup(browser.page_source, 'lxml')
        page_names = page.find_all('span', class_ = 'actor-name')
        page_titles = page.find_all('p', class_ = 'subline-level-1')
        page_locations = page.find_all('p', class_ = 'subline-level-2')
        page_profiles = page.find_all('a', class_ = 'search-result__result-link')
        
        # Put scraped data into a dataframe
        names = list(map(lambda x: x.text, page_names))
        titles = list(map(lambda x: x.text.replace('\n', ''), page_titles))
        
        #print ("Titles of users:", titles)
        locations = list(map(lambda x: x.text.replace('\n', ''), page_locations))
        profiles = list(map(lambda x: "https://www.linkedin.com" + x['href'], page_profiles))[::2]
        temp = pd.DataFrame({'name':names, 'title':titles, 'location':locations, 'profile':profiles})
        df = pd.concat([df, temp])
        print ("**********")
        print (df.shape)
        time.sleep(5)
        cur_page += 1
        
    # Reset dataframe index
    df = df.reset_index()
    df = df.drop(['index'], axis =1)
    df["role"] = role
    final_df = pd.concat([final_df, df])
    final_df = final_df.reset_index()
    final_df = final_df.drop(['index'], axis =1)
final_df["role"] = final_df["role"].apply(lambda x:x.replace("%20","_"))    
# Export results
final_df.to_csv("..//data/profile_data/"+"output_profile_links_bs_"+ str(start_page)+"_"+ str(end_page)+ ".csv", index = False)

# Close Selenium
browser.quit()
# Out:
# hello  11
# /Users/kaushik-shakkari/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# **********
# (5, 5)
# hello  12
# **********
# (10, 5)
# hello  13
# **********
# (15, 5)
# hello  14
# **********
# (20, 5)
# hello  15
# **********
# (25, 5)
# hello  16
# **********
# (30, 5)
# hello  17
# **********
# (35, 5)
# hello  18
# **********
# (40, 5)
# hello  19
# **********
# (45, 5)
# hello  20
# **********
# (50, 5)
# /Users/kaushik-shakkari/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:52: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# hello  11
# **********
# (5, 5)
# hello  12
# **********
# (10, 5)
# hello  13
# **********
# (15, 5)
# hello  14
# **********
# (20, 5)
# hello  15
# **********
# (25, 5)
# hello  16
# **********
# (30, 5)
# hello  17
# **********
# (35, 5)
# hello  18
# **********
# (40, 5)
# hello  19
# **********
# (45, 5)
# hello  20
# **********
# (50, 5)
# hello  11
# **********
# (5, 5)
# hello  12
# **********
# (15, 5)
# hello  13
# **********
# (21, 5)
# hello  14
# **********
# (26, 5)
# hello  15
# **********
# (31, 5)
# hello  16
# **********
# (36, 5)
# hello  17
# **********
# (41, 5)
# hello  18
# **********
# (46, 5)
# hello  19
# **********
# (51, 5)
# hello  20
# **********
# (56, 5)
# hello  11
# **********
# (5, 5)
# hello  12
# **********
# (10, 5)
# hello  13
# **********
# (15, 5)
# hello  14
# **********
# (20, 5)
# hello  15
# **********
# (27, 5)
# hello  16
# **********
# (32, 5)
# hello  17
# **********
# (37, 5)
# hello  18
# **********
# (42, 5)
# hello  19
# **********
# (47, 5)
# hello  20
# **********
# (52, 5)
# hello  11
# **********
# (5, 5)
# hello  12
# **********
# (10, 5)
# hello  13
# **********
# (15, 5)
# hello  14
# **********
# (20, 5)
# hello  15
# **********
# (25, 5)
# hello  16
# **********
# (30, 5)
# hello  17
# **********
# (35, 5)
# hello  18
# **********
# (40, 5)
# hello  19
# **********
# (45, 5)
# hello  20
# **********
# (50, 5)
# hello  11
# **********
# (5, 5)
# hello  12
# **********
# (10, 5)
# hello  13
# **********
# (15, 5)
# hello  14
# **********
# (20, 5)
# hello  15
# **********
# (25, 5)
# hello  16
# **********
# (30, 5)
# hello  17
# **********
# (35, 5)
# hello  18
# **********
# (40, 5)
# hello  19
# **********
# (45, 5)
# hello  20
# **********
# (50, 5)

# %%
final_df
# Out:
#                                               location  \
# 0                         Greater Los Angeles Area
# 1                         Greater Los Angeles Area
# 2                         Greater Los Angeles Area
# 3                                    United States
# 4                         Greater Los Angeles Area
# 5                         Greater Los Angeles Area
# 6                   Orange County, California Area
# 7                         Greater Los Angeles Area
# 8                         Greater Los Angeles Area
# 9                           San Francisco Bay Area
# 10                        Greater Los Angeles Area
# 11                  Orange County, California Area
# 12                        Greater Los Angeles Area
# 13                        Greater Los Angeles Area
# 14                              Austin, Texas Area
# 15                  Orange County, California Area
# 16                        Greater Los Angeles Area
# 17                        Greater Los Angeles Area
# 18                        Greater Los Angeles Area
# 19                        Greater Los Angeles Area
# 20                        Greater Los Angeles Area
# 21                          San Francisco Bay Area
# 22                  Orange County, California Area
# 23                  Orange County, California Area
# 24                        Greater Los Angeles Area
# 25                  Orange County, California Area
# 26                        Greater Los Angeles Area
# 27           Los Angeles, California, United States...
# 28                        Greater Los Angeles Area
# 29                                   United States
# ..                                                 ...
# 278             Burbank, California, United States
# 279                       Greater Los Angeles Area
# 280                  Los Angeles Metropolitan Area
# 281                       Greater Los Angeles Area
# 282                 Orange County, California Area
# 283                 Orange County, California Area
# 284          Rancho Palos Verdes, California, Unite...
# 285                       Greater Los Angeles Area
# 286                       Greater Los Angeles Area
# 287          Los Angeles, California, United States...
# 288                       Greater Los Angeles Area
# 289                       Greater Los Angeles Area
# 290              Irvine, California, United States
# 291          Beverly Hills, California, United Stat...
# 292          Costa Mesa, California, United States
# 293                     Greater New York City Area
# 294                       Greater Los Angeles Area
# 295                                  United States
# 296                       Greater Los Angeles Area
# 297                       Greater Los Angeles Area
# 298                       Greater Los Angeles Area
# 299                                  United States
# 300                                  United States
# 301                       Greater Los Angeles Area
# 302                       Greater Los Angeles Area
# 303                       Greater Los Angeles Area
# 304                 Orange County, California Area
# 305                       Greater Los Angeles Area
# 306                       Greater Los Angeles Area
# 307              Irvine, California, United States
#
#                           name  \
# 0              Heather Alcaraz
# 1                   Samja Kout
# 2                  emma thomas
# 3                 Sanjay Bagai
# 4              Michelle Rosoff
# 5              Eric De Dominic
# 6       Adriana Aden Rodrigues
# 7                Sarah Rumball
# 8                Tina Campbell
# 9         Keiyana Arnold, MSOM
# 10   Alexandra (Ehrlich) Bader
# 11                Alex Dickson
# 12             Connor Bradford
# 13         Yu (Sebastian) DENG
# 14              McKenzie Gibbs
# 15                    David L.
# 16            Melissa Lankhaar
# 17   George Lindner, CIR, ACIR
# 18                   Chip Peck
# 19               Kelly Tanchum
# 20           Jessie Stackhouse
# 21                  Chris Shaw
# 22                Britta Dance
# 23              Alexa Marciano
# 24           Celeste Joy Perez
# 25                  Katie Ryan
# 26              Brianne Nelson
# 27              Maryna Shuliak
# 28                 Javier Reed
# 29               Alex McDonald
# ..                         ...
# 278        Michael J. Wodnicki
# 279             Robert Palfini
# 280                Polwin Chan
# 281                Sarah Zerga
# 282             Sriram Grandhi
# 283              Adam Hamilton
# 284         Isaac Brunell P.E.
# 285                     Ish S.
# 286               Ross Epstein
# 287              Asim Alrashed
# 288               Robert Fritz
# 289              Abeer Mujtaba
# 290               Kelvin Ulloa
# 291             Thomas Barnett
# 292              Jared Sielaff
# 293             Shivani Vartak
# 294                    Evan Yu
# 295       Oluwafemi Aregbesola
# 296              Reed Ginsberg
# 297                Dhiraj Malu
# 298            Liwaans Amuthan
# 299       Soroush Setayeshpour
# 300               Narendra Mal
# 301                 Yinghui Hu
# 302               Vinny Mittal
# 303              Mary Laurance
# 304                Yashas Khot
# 305               Tapan Gandhi
# 306                Mehul Patel
# 307              Ambarneil Roy
#
#                                                profile                 role  \
# 0          https://www.linkedin.com/in/heatheralcaraz/            recruiter
# 1     https://www.linkedin.com/in/samja-kout-86617aab/            recruiter
# 2    https://www.linkedin.com/in/emma-thomas-7a6071...            recruiter
# 3                  https://www.linkedin.com/in/sbagai/            recruiter
# 4    https://www.linkedin.com/in/michelle-rosoff-0b...            recruiter
# 5           https://www.linkedin.com/in/ericdedominic/            recruiter
# 6             https://www.linkedin.com/in/adrianaaden/            recruiter
# 7           https://www.linkedin.com/in/sarah-rumball/            recruiter
# 8           https://www.linkedin.com/in/tinacampbell1/            recruiter
# 9          https://www.linkedin.com/in/keiyana-arnold/            recruiter
# 10   https://www.linkedin.com/in/alexandra-ehrlich-...            recruiter
# 11   https://www.linkedin.com/in/alex-dickson-9489a...            recruiter
# 12         https://www.linkedin.com/in/connorbradford/            recruiter
# 13   https://www.linkedin.com/in/yu-sebastian-deng-...            recruiter
# 14   https://www.linkedin.com/in/mckenzie-gibbs-a33...            recruiter
# 15              https://www.linkedin.com/in/davidlowy/            recruiter
# 16   https://www.linkedin.com/in/melissa-lankhaar-3...            recruiter
# 17   https://www.linkedin.com/in/george-lindner-cir...            recruiter
# 18               https://www.linkedin.com/in/chippeck/            recruiter
# 19   https://www.linkedin.com/in/kelly-tanchum-8304...            recruiter
# 12                🤖 Executive Recruiter at Jobot 🤖
# 13           Tencent Global Recruiter | UCLA Bruin ...
# 14                             Recruiter at Google
# 15               Technical and Executive recruiter
# 16                              Creative Recruiter
# 17           Senior Technical Recruiter at TopTech ...
# 18                   Sr. Recruiter at INNOCEAN USA
# 19                              Recruiter at Apple
# 20           National Recruiter & Owner of Just Fit...
# 21                   Technical Recruiter at Apple
# 22                   Technical Recruiter at Amazon
# 23           Senior Creative Recruiter at Creative ...
# 24                            Recruiter at Netflix
# 25                                Recruiter at PSI
# 26                                Senior Recruiter
# 27              Recruiter at Elite Club Recruiting
# 28                            Recruiter at Aerotek
# 29                             Technical Recruiter
# ..                                                 ...
# 278                            Mechanical Engineer
# 279          Mechanical Engineer at Adsys Controls,...
# 280          Principal Mechanical Engineer at Rayth...
# 281          Mechanical Engineer at NASA Jet Propul...
# 282          Mechanical Engineer with technical lea...
# 283          Mechanical Engineer with a Systems emp...
# 284                     Senior Mechanical Engineer
# 285          Mechanical Engineer at NovaWurks, Inc....
# 286                            Mechanical Engineer
# 287                            Mechanical Engineer
# 288          Hydro-Mechanical Engineer III at Crane...
# 289           Senior Mechanical Engineer at Safran
# 290          Mechanical Engineer | Operations Manag...
# 291                            Mechanical Engineer
# 292                            Mechanical Engineer
# 293          Mechanical Engineer | Robotics(ROS) an...
# 294          Mechanical Engineer, Founding Team at ...
# 295             Mechanical Engineer at OneH2, Inc.
# 296           Mechanical Design Engineer at SpaceX
# 297          Device Engineer at Now Diagnostics | M...
# 298          Thermal & Mechanical Engineer | CFD En...
# 299                            Mechanical Engineer
# 300                  Mechanical Engineer at Vertiv
# 301          Software Engineer | Mechanical Enginee...
# 302          Mechanical Design Engineer at IDS Grou...
# 303          Process Optimization Engineer with SUE...
# 304          Mechanical Engineer with experience in...
# 305          Application Engineer | MS- Mechanical ...
# 306                     Mechanical Design Engineer
# 307          Quality Engineer| Graduate Mechanical ...
#
# [308 rows x 5 columns]

# %%
final_df["role"] = final_df["role"].apply(lambda x:x.replace("%20","_"))

# %%
final_df.sample(5)
# Out:
#                                  location            name  \
# 155               Greater Denver Area      Haneesha Narra
# 271          Greater Los Angeles Area        Kevin Kayser
# 279          Greater Los Angeles Area      Robert Palfini
# 205              Greater Seattle Area        Robbie Oyama
# 77           Greater Los Angeles Area       Mark Bordelon
#
#                                                profile                  role  \
# 155        https://www.linkedin.com/in/haneesha-narra/      network_engineer
# 271          https://www.linkedin.com/in/kevin-kayser/   mechanical_engineer
# 279         https://www.linkedin.com/in/robertpalfini/   mechanical_engineer
# 205           https://www.linkedin.com/in/robbieoyama/  sales_representative
# 77   https://www.linkedin.com/in/mark-bordelon-166693/     software_engineer
#
#                                                  title
# 155          Network Engineer at Charter Communicat...
# 271          Mechanical Engineer at Argos Engineers...
# 279          Mechanical Engineer at Adsys Controls,...
# 205                Sales Representative at Pearson
# 77               Software Developer at Live Nation

# %%
final_df.to_csv("..//data/profile_data/"+"output_profile_links_"+ str(start_page)+"_"+ str(end_page)+ ".csv", index = False)

# %%
final_df = final_df.loc[213:].reset_index()

# %%
final_df = final_df.drop(['index'], axis = 1)

# %%
final_df.to_csv("..//data/profile_data/"+"output_profile_links_"+ str(start_page)+"_"+ str(end_page)+ ".csv", index = False)
