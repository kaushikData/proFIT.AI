# %% [markdown]
# # Importing Libraries

# %%
import csv
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Crawling current and past experience of employees on LinkedIn

# %% [markdown]
# ## Bot Logging into LinkedIn

# %%
linkedin = 'https://www.linkedin.com/login?fromSignIn=true&trk=guest_homepage-basic_nav-header-signin'

# open LinkedIn loginpage on chrome using chrome driver using Selenium
browser = webdriver.Chrome(executable_path='/Users/kaushik-shakkari/Downloads/chromedriver')
browser.get(linkedin)
time.sleep(2)

# Logging into LinkedIn
email = browser.find_element_by_name('session_key')
password = browser.find_element_by_name('session_password')
email.send_keys("shakkari@usc.edu")
password.send_keys("biglion333")
browser.find_element_by_xpath('//*[@type="submit"]').click()
time.sleep(2)

# %% [markdown]
# ## Importing crawled employee profile data

# %%
profile_df = pd.read_csv("../data/profile_data/output_search_uber_data%20scientist%20.csv")
profile_df.head()
# Out:
#              name                               title  \
# 0       Mike Yung           Data Scientist @ Uber
# 1        Jing Pan          Data Scientist at Uber
# 2      Steve Yang          Data Scientist at Uber
# 3  Xinjiang Xiang          Data Scientist at Uber
# 4   Akshay Tiwari          Data Scientist at Uber
#
#                                             location  \
# 0          Los Angeles, California, United States...
# 1                       Greater Los Angeles Area
# 2                       Greater Los Angeles Area
# 3                       Greater Los Angeles Area
# 4                         San Francisco Bay Area
#
#                                              profile
# 0              https://www.linkedin.com/in/mikeyung/
# 1           https://www.linkedin.com/in/jingpan1019/
# 2          https://www.linkedin.com/in/steve-s-yang/
# 3  https://www.linkedin.com/in/xinjiang-xiang-b82...
# 4        https://www.linkedin.com/in/akshaytiwari19/

# %% [markdown]
# ## Extract employee experiences using tags

# %%
#for link in r.loc[0:5,'profile']:
experience_df = pd.DataFrame(columns=["profile_url","job_title","company","period","years_exp","experience_description"])

#for i in range(profile_df.shape[0]):
for i in range(2):
    link = profile_df.loc[i,'profile']
    print ("*************************************************************************")
    print (i)
    
    try:

        browser.get(link)
        
        """
        SCROLL_PAUSE_TIME = 5
        #getting scroll height
        last_height = browser.execute_script("return document.body.scrollHeight")
        for i in range(5):
        #Scroll Down to bottom
            browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

            #Wait to load the page
            time.sleep(SCROLL_PAUSE_TIME)
            # Calculate the new scroll height nd compare last scroll height
            new_height = browser.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height 
        """      
            
        src = browser.page_source
        soup = BeautifulSoup(src, 'lxml')
        print (soup)

        exp_section = soup.find('section',class_='pv-profile-section experience-section ember-view')
        print ("exp_section: ", str(exp_section)[:20])
        li_tags = exp_section.find_all('div', class_='display-flex flex-column full-width')
        a_tags = []
        for i in range(len(li_tags)):
            a_tags.append(li_tags[i].find('a'))
        job_titles = list(map(lambda x:x.find('h3').get_text().strip(), a_tags))
        print ("job: ",len(job_titles))
        print (job_titles)
        company = list(map(lambda x:x.find_all('p')[1].get_text().strip(), a_tags))
        print ("company: ",len(job_titles))
        print (company)
        period = list(map(lambda x:x.find_all('h4')[0].find_all('span')[1].get_text().strip(), a_tags))
        print ("period: ",len(period))
        print (period)
        years_exp = list(map(lambda x:x.find_all('h4')[1].find_all('span')[1].get_text().strip(), a_tags))
        print ("period: ",len(years_exp))
        print (years_exp)
        exp_roles_resps = exp_section.find_all("div", class_= "pv-entity__extra-details t-14 t-black--light ember-view")

        experience = []
        for exp_roles_resp in exp_roles_resps:
            for tag in exp_roles_resp.find_all('span'):
                tag.replace_with('')
            experience.append(str(exp_roles_resp).replace("<!-- --></p><!-- --></div>","").split(';">')[1].strip())
        print ("experience: ",len(experience))
        print (experience)

        temp_df = pd.DataFrame({'profile_url':link, 'job_title':job_titles, 'company':company, 'period':period, 'years_exp':years_exp, 'experience_description':experience[:len(job_titles)]})
        experience_df = pd.concat([experience_df, temp_df])
        experience_df.to_csv("../data/experience_data.csv")
    except Exception as e:
        print (e)
# Out:
# *************************************************************************
# 0
# [<section class="artdeco-toasts" id="artdeco-toasts">
# <header class="artdeco-toasts__header">
# <h2 class="artdeco-toasts__title">
#         0 notifications total
#       </h2>
# </header>
# <!-- -->
# <ul aria-atomic="true" aria-live="assertive" class="artdeco-toasts_toasts">
# <!-- --> </ul>
# </section>, <section class="pv-ad-banner--light ad-banner-container is-header-zone ember-view" id="ember50" render-method="default"><iframe class="ad-banner" height="17" scrolling="no" src="about:blank" title="advertisement" width="100%"></iframe>
# <!-- --></section>, <section class="pv-top-card artdeco-card ember-view" id="ember53"><!-- -->
# <div class="profile-background-image ember-view" id="ember54" tabindex="0"> <div class="profile-background-image__image-container">
# <img alt="Background Image" class="profile-background-image__image relative full-width full-height" id="profile-background-image-target-image" src="https://media-exp1.licdn.com/dms/image/C5616AQFpPp0VOJiyGA/profile-displaybackgroundimage-shrink_200_800/0?e=1596672000&amp;v=beta&amp;t=nY2j1PGLDidZU22dIkWSq8SoAd9SNaX0ahgiHrbusXg" style=""/>
# </div>
# </div>
# <div class="ph5 pb5">
# <div class="display-flex">
# <div class="pv-top-card--photo text-align-left">
# <div class="pv-top-card__photo-wrapper ml0">
# <div class="presence-entity pv-top-card__image presence-entity--size-9 ember-view" id="ember57"><img alt="Mike Yung" class="pv-top-card__photo presence-entity__image EntityPhoto-circle-9 lazy-image ember-view" id="ember58" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C5603AQFh5LjwCNBj0A/profile-displayphoto-shrink_400_400/0?e=1596672000&amp;v=beta&amp;t=gcqh4W-xM9JWFaCB3J9eiX-qNRrsUIfRJkBhI5vzXdY" title="Mike Yung"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-9 presence-indicator hidden presence-indicator--size-9 ember-view" id="ember59">
# <span class="visually-hidden">
#     Status is offline
#   </span></div></div>
# </div>
# <!-- -->
# </div>
# <div class="flex-1 flex-column display-flex mt3 mb1">
# <div class="display-flex justify-flex-end align-items-center">
# <div class="mt1 inline-flex align-items-center ember-view" id="ember61"><span class="ember-view" id="ember62"> <a class="message-anywhere-button pv-s-profile-actions pv-s-profile-actions--message ml2 artdeco-button artdeco-button--2 artdeco-button--primary" data-ember-action="" data-ember-action-64="64" disabled="" href="/messaging/thread/6591684934925193216?controlUrn=compose_message_button&amp;referringModuleKey=NON_SELF_PROFILE_VIEW">
# <!-- -->        Message
#     </a>
# </span><!-- --><!-- --><div class="pv-s-profile-actions__overflow ember-view" id="ember65"><div class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-left ember-view" id="ember66"><button aria-expanded="false" class="ml2 pv-s-profile-actions__overflow-toggle artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view" id="ember67" tabindex="0" type="button"> <span>More…</span>
# <!-- --></button>
# <div aria-hidden="true" class="pv-s-profile-actions__overflow-dropdown display-flex artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-left artdeco-dropdown__content--placement-bottom ember-view" id="ember68" tabindex="-1"><div class="artdeco-dropdown__content-inner">
# <ul class="full-width">
# <li class="ember-view" id="ember70"><div class="ember-view" id="ember71"><div class="pv-s-profile-actions pv-s-profile-actions--share-profile pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember72" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="share-linkedin-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M24 12a1.18 1.18 0 00-.36-.84L14 2v6h-3A10 10 0 001 18v4h1.87A6.11 6.11 0 019 16h5v6l9.63-9.14A1.18 1.18 0 0024 12zm-8 5.54V14H9a8.15 8.15 0 00-6 2.84A8 8 0 0111 10h5V6.48L21.81 12z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Share Profile via Message</span>
# <span class="a11y-text">Share Mike Yung’s profile via message</span>
# </div></div>
# <div class="pv-s-profile-actions__share-profile-button hidden ember-view" id="ember73"> <button aria-label="Send group message to " class="message-anywhere-button" data-ember-action="" data-ember-action-74="74" type="button">
#         Message
#     </button>
# </div>
# </li>
# <li class="ember-view" id="ember76"><div class="ember-view" id="ember77"><div class="pv-s-profile-actions pv-s-profile-actions--save-to-pdf pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember78" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="download-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M21 15v5a1 1 0 01-1 1H4a1 1 0 01-1-1v-5h2v4h14v-4h2zm-9 1a1 1 0 00.71-.29l5.29-5.3-1.29-1.29L13 12.83V2h-2v10.83L7.29 9.12 6 10.41l5.29 5.29a1 1 0 00.71.3z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Save to PDF</span>
# <span class="a11y-text">Save Mike Yung’s profile to PDF</span>
# </div></div>
# </li>
# <li class="ember-view" id="ember80"><div aria-label="Give Kudos to Mike Yung" class="p0 artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember81"><!-- --><div class="appr-trigger ember-view" data-control-name="appreciate" id="ember82"><button class="pv-s-profile-actions pv-s-profile-actions--appreciate pv-s-profile-actions__overflow-button full-width text-align-left artdeco-button artdeco-button--2 artdeco-button--tertiary ember-view" id="ember83" type="button"><!-- -->
# <span class="artdeco-button__text">
# <li-icon aria-hidden="true" class="pv-s-profile-actions__label t-black--light" size="large" type="achievement-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M16.88 13a7 7 0 10-9.76 0l-2.48 7.31a.52.52 0 00.48.69h.15l2.54-.68 1.6 2.09a.52.52 0 00.91-.15L12 17.3l1.69 4.94a.5.5 0 00.49.35.52.52 0 00.42-.2l1.6-2.09 2.54.7h.15a.52.52 0 00.48-.69zm-10-5A5.13 5.13 0 1112 13.13 5.13 5.13 0 016.88 8zm2.48 11.24l-.83-1.07-1.31.35 1.48-4.34a7 7 0 002.12.72zm6.11-1.07l-.82 1.07-1.49-4.34a7 7 0 002.14-.72l1.48 4.34zM12 5.88A2.13 2.13 0 119.88 8 2.13 2.13 0 0112 5.88M12 5a3 3 0 103 3 3 3 0 00-3-3z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="pv-s-profile-actions__label t-14 t-black--light t-normal">Give Kudos</span>
# </span></button>
# <!-- --></div></div>
# <!-- --></li>
# <li class="ember-view" id="ember86"><div class="ember-view" id="ember87"><div class="pv-s-profile-actions pv-s-profile-actions--request-recommendation pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember88" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="quote-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.1 12.5c1.7-2.5 1-5.9-1.6-7.6S2.6 3.9.9 6.5s-1 5.9 1.6 7.6c.9.6 2 .9 3 .9h.6l-2.8 4 1.5 1 5.3-7.5zm13 0c1.7-2.5 1-5.9-1.6-7.6s-5.9-1-7.6 1.6-1 5.9 1.6 7.6c.9.6 2 .9 3 .9h.6l-2.8 4 1.5 1 5.3-7.5z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Request a Recommendation</span>
# <span class="a11y-text">Request Mike Yung’s recommendation</span>
# </div></div>
# </li>
# <li class="ember-view" id="ember90"><div class="ember-view" id="ember91"><div class="pv-s-profile-actions pv-s-profile-actions--recommend pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember92" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="speech-bubble-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M18 10H6V9h12v1zm4-5v17l-5-4H3a1 1 0 01-1-1V5a1 1 0 011-1h18a1 1 0 011 1zm-2 1H4v10h13.7l2.3 1.84V6zm-4 6H8v1h8v-1z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Recommend</span>
# <span class="a11y-text">Write a recommendation for Mike Yung</span>
# </div></div>
# </li>
# <li class="ember-view" id="ember94"><div class="ember-view" id="ember95"><div class="pv-s-profile-actions pv-s-profile-actions--unfollow pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember96" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="block-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M12 2C6.5 2 2 6.5 2 12s4.5 10 10 10 10-4.5 10-10S17.5 2 12 2zM3.9 12c0-4.5 3.6-8.1 8.1-8.1 1.9 0 3.7.7 5 1.8L5.6 17c-1.1-1.3-1.7-3.1-1.7-5zm8.1 8.1c-1.9 0-3.7-.7-5-1.8L18.4 7c1.1 1.4 1.8 3.1 1.8 5-.1 4.5-3.7 8.1-8.2 8.1z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Unfollow</span>
# <span class="a11y-text">Unfollow Mike Yung</span>
# </div></div>
# </li>
# <li class="ember-view" id="ember98"><div class="ember-view" id="ember99"><div class="pv-s-profile-actions pv-s-profile-actions--disconnect pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember100" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="person-remove-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M16.45 14L13 12.66v-1.83A8 8 0 0014 7V6a4 4 0 00-8 0v1a8 8 0 001 3.86v1.84L3.55 14A4 4 0 001 17.73V20a1 1 0 001 1h16a1 1 0 001-1v-2.27A4 4 0 0016.45 14zM8 5.85a2 2 0 014 0v1.3a6 6 0 01-.71 2.85l-.29.6a1 1 0 01-.88.53h-.2A1 1 0 019 10.6l-.29-.6A6 6 0 018 7.16V5.85zM17 19H3v-1.38a2 2 0 011.26-1.86L9 13.92v-1.1a3 3 0 001 .18 3 3 0 001-.18v1.1l4.72 1.8A2 2 0 0117 17.58V19zm4.33-10L24 11.67 22.67 13 20 10.33 17.33 13 16 11.67 18.67 9 16 6.33 17.33 5 20 7.67 22.67 5 24 6.33z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Remove Connection</span>
# <span class="a11y-text">Remove your connection to Mike Yung</span>
# </div></div>
# </li>
# <li class="ember-view" id="ember102"><div class="ember-view" id="ember103"><div class="pv-s-profile-actions pv-s-profile-actions--report pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember104" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="flag-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M13.82 5L14 4a1 1 0 00-1-1H5V2H3v20h2v-7h4.18L9 16a1 1 0 001 1h8.87L21 5h-7.18zM5 13V5h6.94l-1.41 8H5zm12.35 2h-6.3l1.42-8h6.29z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Report / Block</span>
# <span class="a11y-text">Report or block Mike Yung’s profile</span>
# </div></div>
# <!-- --></li>
# </ul>
# </div>
# </div></div>
# </div></div>
# <!-- --> </div>
# </div>
# </div>
# <div class="display-flex mt2">
# <div class="flex-1 mr5">
# <ul class="pv-top-card--list inline-flex align-items-center">
# <li class="inline t-24 t-black t-normal break-words">
#             Mike Yung
#           </li>
# <li class="pv-top-card__distance-badge inline-block v-align-text-bottom t-16 t-black--light t-normal"><span class="distance-badge separator">
# <span class="visually-hidden">1st degree connection</span><span aria-hidden="true" class="dist-value">1st</span>
# </span></li>
# <!-- --> <li class="inline-flex ml2">
# <span class="pv-member-badge--for-top-card inline-flex pv-member-badge ember-view" id="ember105" style="display: none;"><!-- -->
# <!-- -->
# <span class="visually-hidden">
#   Mike has a  account
# </span>
# <!-- --></span>
# </li>
# </ul>
# <h2 class="mt1 t-18 t-black t-normal break-words">
#             Data Scientist @ Uber
#           </h2>
# <ul class="pv-top-card--list pv-top-card--list-bullet mt1">
# <li class="t-16 t-black t-normal inline-block">
#               Los Angeles, California, United States
#             </li>
# <!-- -->
# <li class="inline-block">
# <a class="ember-view" data-control-name="topcard_view_all_connections" href="/search/results/people/?facetConnectionOf=%5B%22ACoAAAefAx4B4PgBKTYSpCCrRJ8NJVJVAujL_a8%22%5D&amp;facetNetwork=%5B%22F%22%2C%22S%22%5D&amp;origin=MEMBER_PROFILE_CANNED_SEARCH" id="ember106"> <span class="t-16 t-bold">
#                     500+ connections
#                   </span>
# </a> </li>
# <li class="inline-block">
# <a class="ember-view" data-control-name="contact_see_more" href="/in/mikeyung/detail/contact-info/" id="ember107"> <span class="t-16 t-bold">
#                 Contact info
#               </span>
# </a> </li>
# </ul>
# </div>
# <div>
# <ul class="pv-top-card--experience-list">
# <li>
# <a class="pv-top-card--experience-list-item" data-control-name="position_see_more" data-ember-action="" data-ember-action-109="109" href="#">
# <img class="EntityPhoto-square-1 flex-shrink-zero ember-view" id="ember110" src="https://media-exp1.licdn.com/dms/image/C4D0BAQFiYnR1Mbtxdg/company-logo_100_100/0?e=1599091200&amp;v=beta&amp;t=AfHZCuGggindEmOxFfwrKjZ5ms0OOEn5SX8xdpsq5KQ"/>
# <span class="text-align-left ml2 t-14 t-black t-bold full-width lt-line-clamp lt-line-clamp--multi-line ember-view" id="ember111" style="-webkit-line-clamp: 2">  Uber
#
# <!-- --></span>
# </a>
# </li>
# <li>
# <a class="pv-top-card--experience-list-item" data-control-name="education_see_more" data-ember-action="" data-ember-action-113="113" href="#">
# <img class="EntityPhoto-square-1 flex-shrink-zero ember-view" id="ember114" src="https://media-exp1.licdn.com/dms/image/C4E0BAQHnbnsnJlBiZg/company-logo_100_100/0?e=1599091200&amp;v=beta&amp;t=YQWSV-gsP9rKG_lRkwT5I-fUHNmPWe69A41Ht7vS7G0"/>
# <span class="text-align-left ml2 t-14 t-black t-bold full-width lt-line-clamp lt-line-clamp--multi-line ember-view" id="ember115" style="-webkit-line-clamp: 2">  University of Pennsylvania
#
# <!-- --></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- -->
# <!-- --> </div>
# </section>, <section class="ad-banner-container ember-view" id="ember140" render-method="default"><iframe class="ad-banner" height="250" scrolling="no" src="about:blank" title="advertisement" width="300"></iframe>
# <!-- --></section>, <section class="ad-banner-container ember-view" id="ember147" render-method="default"><iframe class="ad-banner" height="250" scrolling="no" src="about:blank" title="advertisement" width="300"></iframe>
# <!-- --></section>, <section class="entity-hovercard__loading-state">
#       Loading…
#     </section>]
# exp_section:  None
# 'NoneType' object has no attribute 'find_all'
# *************************************************************************
# 1
# [<section class="artdeco-toasts" id="artdeco-toasts">
# <header class="artdeco-toasts__header">
# <h2 class="artdeco-toasts__title">
#         0 notifications total
#       </h2>
# </header>
# <!-- -->
# <ul aria-atomic="true" aria-live="assertive" class="artdeco-toasts_toasts">
# <!-- --> </ul>
# </section>, <section class="pv-ad-banner--light ad-banner-container is-header-zone ember-view" id="ember50" render-method="default"><iframe class="ad-banner" height="17" scrolling="no" src="about:blank" title="advertisement" width="100%"></iframe>
# <!-- --></section>, <section class="pv-top-card artdeco-card ember-view" id="ember53"><!-- -->
# <div class="profile-background-image profile-background-image--loading ember-view" id="ember54" tabindex="0"><!-- --></div>
# <div class="ph5 pb5">
# <div class="display-flex">
# <div class="pv-top-card--photo text-align-left">
# <div class="pv-top-card__photo-wrapper ml0">
# <div class="presence-entity pv-top-card__image presence-entity--size-9 ember-view" id="ember56"><img alt="Jing Pan" class="pv-top-card__photo presence-entity__image EntityPhoto-circle-9 lazy-image ember-view" id="ember57" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C4E03AQFJ9lsBpARIwA/profile-displayphoto-shrink_400_400/0?e=1596672000&amp;v=beta&amp;t=ORZPt1XAxPUGW-NwBFJYCWDDA54d-GhA7mhRyH78mZQ" title="Jing Pan"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-9 presence-indicator presence-indicator--is-reachable presence-indicator--size-9 ember-view" id="ember58">
# <span class="visually-hidden">
#     Status is reachable
# </span></div></div>
# </div>
# <!-- -->
# </div>
# <div class="flex-1 flex-column display-flex mt3 mb1">
# <div class="display-flex justify-flex-end align-items-center">
# <div class="mt1 inline-flex align-items-center ember-view" id="ember60"><span class="ember-view" id="ember61"> <a class="message-anywhere-button pv-s-profile-actions pv-s-profile-actions--message ml2 artdeco-button artdeco-button--2 artdeco-button--primary" data-ember-action="" data-ember-action-63="63" disabled="" href="/messaging/thread/6445771682539012096?controlUrn=compose_message_button&amp;referringModuleKey=NON_SELF_PROFILE_VIEW">
# <!-- -->        Message
#     </a>
# </span><!-- --><!-- --><div class="pv-s-profile-actions__overflow ember-view" id="ember64"><div class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-left ember-view" id="ember65"><button aria-expanded="false" class="ml2 pv-s-profile-actions__overflow-toggle artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view" id="ember66" tabindex="0" type="button"> <span>More…</span>
# <!-- --></button>
# <div aria-hidden="true" class="pv-s-profile-actions__overflow-dropdown display-flex artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-left artdeco-dropdown__content--placement-bottom ember-view" id="ember67" tabindex="-1"><div class="artdeco-dropdown__content-inner">
# <ul class="full-width">
# <li class="ember-view" id="ember69"><div class="ember-view" id="ember70"><div class="pv-s-profile-actions pv-s-profile-actions--share-profile pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember71" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="share-linkedin-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M24 12a1.18 1.18 0 00-.36-.84L14 2v6h-3A10 10 0 001 18v4h1.87A6.11 6.11 0 019 16h5v6l9.63-9.14A1.18 1.18 0 0024 12zm-8 5.54V14H9a8.15 8.15 0 00-6 2.84A8 8 0 0111 10h5V6.48L21.81 12z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Share Profile via Message</span>
# <span class="a11y-text">Share Jing Pan’s profile via message</span>
# </div></div>
# <div class="pv-s-profile-actions__share-profile-button hidden ember-view" id="ember72"> <button aria-label="Send group message to " class="message-anywhere-button" data-ember-action="" data-ember-action-73="73" type="button">
#         Message
#     </button>
# </div>
# </li>
# <li class="ember-view" id="ember75"><div class="ember-view" id="ember76"><div class="pv-s-profile-actions pv-s-profile-actions--save-to-pdf pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember77" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="download-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M21 15v5a1 1 0 01-1 1H4a1 1 0 01-1-1v-5h2v4h14v-4h2zm-9 1a1 1 0 00.71-.29l5.29-5.3-1.29-1.29L13 12.83V2h-2v10.83L7.29 9.12 6 10.41l5.29 5.29a1 1 0 00.71.3z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Save to PDF</span>
# <span class="a11y-text">Save Jing Pan’s profile to PDF</span>
# </div></div>
# </li>
# <li class="ember-view" id="ember79"><div aria-label="Give Kudos to Jing Pan" class="p0 artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember80"><!-- --><div class="appr-trigger ember-view" data-control-name="appreciate" id="ember81"><button class="pv-s-profile-actions pv-s-profile-actions--appreciate pv-s-profile-actions__overflow-button full-width text-align-left artdeco-button artdeco-button--2 artdeco-button--tertiary ember-view" id="ember82" type="button"><!-- -->
# <span class="artdeco-button__text">
# <li-icon aria-hidden="true" class="pv-s-profile-actions__label t-black--light" size="large" type="achievement-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M16.88 13a7 7 0 10-9.76 0l-2.48 7.31a.52.52 0 00.48.69h.15l2.54-.68 1.6 2.09a.52.52 0 00.91-.15L12 17.3l1.69 4.94a.5.5 0 00.49.35.52.52 0 00.42-.2l1.6-2.09 2.54.7h.15a.52.52 0 00.48-.69zm-10-5A5.13 5.13 0 1112 13.13 5.13 5.13 0 016.88 8zm2.48 11.24l-.83-1.07-1.31.35 1.48-4.34a7 7 0 002.12.72zm6.11-1.07l-.82 1.07-1.49-4.34a7 7 0 002.14-.72l1.48 4.34zM12 5.88A2.13 2.13 0 119.88 8 2.13 2.13 0 0112 5.88M12 5a3 3 0 103 3 3 3 0 00-3-3z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="pv-s-profile-actions__label t-14 t-black--light t-normal">Give Kudos</span>
# </span></button>
# <!-- --></div></div>
# <!-- --></li>
# <li class="ember-view" id="ember85"><div class="ember-view" id="ember86"><div class="pv-s-profile-actions pv-s-profile-actions--request-recommendation pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember87" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="quote-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.1 12.5c1.7-2.5 1-5.9-1.6-7.6S2.6 3.9.9 6.5s-1 5.9 1.6 7.6c.9.6 2 .9 3 .9h.6l-2.8 4 1.5 1 5.3-7.5zm13 0c1.7-2.5 1-5.9-1.6-7.6s-5.9-1-7.6 1.6-1 5.9 1.6 7.6c.9.6 2 .9 3 .9h.6l-2.8 4 1.5 1 5.3-7.5z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Request a Recommendation</span>
# <span class="a11y-text">Request Jing Pan’s recommendation</span>
# </div></div>
# </li>
# <li class="ember-view" id="ember89"><div class="ember-view" id="ember90"><div class="pv-s-profile-actions pv-s-profile-actions--recommend pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember91" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="speech-bubble-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M18 10H6V9h12v1zm4-5v17l-5-4H3a1 1 0 01-1-1V5a1 1 0 011-1h18a1 1 0 011 1zm-2 1H4v10h13.7l2.3 1.84V6zm-4 6H8v1h8v-1z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Recommend</span>
# <span class="a11y-text">Write a recommendation for Jing Pan</span>
# </div></div>
# </li>
# <li class="ember-view" id="ember93"><div class="ember-view" id="ember94"><div class="pv-s-profile-actions pv-s-profile-actions--unfollow pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember95" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="block-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M12 2C6.5 2 2 6.5 2 12s4.5 10 10 10 10-4.5 10-10S17.5 2 12 2zM3.9 12c0-4.5 3.6-8.1 8.1-8.1 1.9 0 3.7.7 5 1.8L5.6 17c-1.1-1.3-1.7-3.1-1.7-5zm8.1 8.1c-1.9 0-3.7-.7-5-1.8L18.4 7c1.1 1.4 1.8 3.1 1.8 5-.1 4.5-3.7 8.1-8.2 8.1z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Unfollow</span>
# <span class="a11y-text">Unfollow Jing Pan</span>
# </div></div>
# </li>
# <li class="ember-view" id="ember97"><div class="ember-view" id="ember98"><div class="pv-s-profile-actions pv-s-profile-actions--disconnect pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember99" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="person-remove-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M16.45 14L13 12.66v-1.83A8 8 0 0014 7V6a4 4 0 00-8 0v1a8 8 0 001 3.86v1.84L3.55 14A4 4 0 001 17.73V20a1 1 0 001 1h16a1 1 0 001-1v-2.27A4 4 0 0016.45 14zM8 5.85a2 2 0 014 0v1.3a6 6 0 01-.71 2.85l-.29.6a1 1 0 01-.88.53h-.2A1 1 0 019 10.6l-.29-.6A6 6 0 018 7.16V5.85zM17 19H3v-1.38a2 2 0 011.26-1.86L9 13.92v-1.1a3 3 0 001 .18 3 3 0 001-.18v1.1l4.72 1.8A2 2 0 0117 17.58V19zm4.33-10L24 11.67 22.67 13 20 10.33 17.33 13 16 11.67 18.67 9 16 6.33 17.33 5 20 7.67 22.67 5 24 6.33z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Remove Connection</span>
# <span class="a11y-text">Remove your connection to Jing Pan</span>
# </div></div>
# </li>
# <li class="ember-view" id="ember101"><div class="ember-view" id="ember102"><div class="pv-s-profile-actions pv-s-profile-actions--report pv-s-profile-actions__overflow-button full-width text-align-left artdeco-dropdown__item artdeco-dropdown__item--is-dropdown ember-view" id="ember103" tabindex="0"><!-- --> <li-icon aria-hidden="true" class="pv-s-profile-actions__overflow-icon" size="large" type="flag-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M13.82 5L14 4a1 1 0 00-1-1H5V2H3v20h2v-7h4.18L9 16a1 1 0 001 1h8.87L21 5h-7.18zM5 13V5h6.94l-1.41 8H5zm12.35 2h-6.3l1.42-8h6.29z"></path>
# </svg></li-icon>
# <span aria-hidden="true" class="display-flex t-normal pv-s-profile-actions__label">Report / Block</span>
# <span class="a11y-text">Report or block Jing Pan’s profile</span>
# </div></div>
# <!-- --></li>
# </ul>
# </div>
# </div></div>
# </div></div>
# <!-- --> </div>
# </div>
# </div>
# <div class="display-flex mt2">
# <div class="flex-1 mr5">
# <ul class="pv-top-card--list inline-flex align-items-center">
# <li class="inline t-24 t-black t-normal break-words">
#             Jing Pan
#           </li>
# <li class="pv-top-card__distance-badge inline-block v-align-text-bottom t-16 t-black--light t-normal"><span class="distance-badge separator">
# <span class="visually-hidden">1st degree connection</span><span aria-hidden="true" class="dist-value">1st</span>
# </span></li>
# <!-- --> <li class="inline-flex ml2">
# <span class="pv-member-badge--for-top-card inline-flex pv-member-badge ember-view" id="ember104" style="display: none;"><!-- -->
# <!-- -->
# <span class="visually-hidden">
#   Jing has a  account
# </span>
# <!-- --></span>
# </li>
# </ul>
# <h2 class="mt1 t-18 t-black t-normal break-words">
#             Data Scientist at Uber
#           </h2>
# <ul class="pv-top-card--list pv-top-card--list-bullet mt1">
# <li class="t-16 t-black t-normal inline-block">
#               Greater Los Angeles Area
#             </li>
# <!-- -->
# <li class="inline-block">
# <a class="ember-view" data-control-name="topcard_view_all_connections" href="/search/results/people/?facetConnectionOf=%5B%22ACoAABYWlsoBwldN5EVnYcJHZpvCZomaIf_ud9g%22%5D&amp;facetNetwork=%5B%22F%22%2C%22S%22%5D&amp;origin=MEMBER_PROFILE_CANNED_SEARCH" id="ember105"> <span class="t-16 t-bold">
#                     500+ connections
#                   </span>
# </a> </li>
# <li class="inline-block">
# <a class="ember-view" data-control-name="contact_see_more" href="/in/jingpan1019/detail/contact-info/" id="ember106"> <span class="t-16 t-bold">
#                 Contact info
#               </span>
# </a> </li>
# </ul>
# </div>
# <div>
# <ul class="pv-top-card--experience-list">
# <li>
# <a class="pv-top-card--experience-list-item" data-control-name="position_see_more" data-ember-action="" data-ember-action-108="108" href="#">
# <img class="EntityPhoto-square-1 flex-shrink-zero ember-view" id="ember109" src="https://media-exp1.licdn.com/dms/image/C4D0BAQFiYnR1Mbtxdg/company-logo_100_100/0?e=1599091200&amp;v=beta&amp;t=AfHZCuGggindEmOxFfwrKjZ5ms0OOEn5SX8xdpsq5KQ"/>
# <span class="text-align-left ml2 t-14 t-black t-bold full-width lt-line-clamp lt-line-clamp--multi-line ember-view" id="ember110" style="-webkit-line-clamp: 2">  Uber
#
# <!-- --></span>
# </a>
# </li>
# <li>
# <a class="pv-top-card--experience-list-item" data-control-name="education_see_more" data-ember-action="" data-ember-action-112="112" href="#">
# <img class="EntityPhoto-square-1 flex-shrink-zero ember-view" id="ember113" src="https://media-exp1.licdn.com/dms/image/C4D0BAQGLlncXGXUvTQ/company-logo_100_100/0?e=1599091200&amp;v=beta&amp;t=fkAsau54jOwMJTQzr6DXFWfFMgdomSTiGoB8z9cKVeQ"/>
# <span class="text-align-left ml2 t-14 t-black t-bold full-width lt-line-clamp lt-line-clamp--multi-line ember-view" id="ember114" style="-webkit-line-clamp: 2">  University of Missouri-Columbia
#
# <!-- --></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- -->
# <!-- --> </div>
# </section>, <section class="ad-banner-container ember-view" id="ember139" render-method="default"><iframe class="ad-banner" height="250" scrolling="no" src="about:blank" title="advertisement" width="300"></iframe>
# <!-- --></section>, <section class="ad-banner-container ember-view" id="ember146" render-method="default"><iframe class="ad-banner" height="250" scrolling="no" src="about:blank" title="advertisement" width="300"></iframe>
# <!-- --></section>, <section class="entity-hovercard__loading-state">
#       Loading…
#     </section>]
# exp_section:  None
# 'NoneType' object has no attribute 'find_all'
